# %%
import pandas as pd
hq=pd.read_csv(r"E:\orderflow\MarketHq\2021-06-05cNonebNoneeNone.csv",header=None)
hq.columns=columns=['no','code','name','time','price','vol','amount','zljk','total_vol','total_amount','eat_dws','zd_vol','zd_amount','bd_vol','bd_amount']
hq
# Out:
#               no    code  name      time   price     vol  amount  zljk  \
# 0        7852125  688161  威高骨科  15:00:00   91.99   15.77  145067   中单买
# 1        7557075  688161  威高骨科  15:00:00   91.99   41.85  384978  大单主买
# 2        7827030  688161  威高骨科  15:00:00   91.99   12.66  116459   中单买
# 3        7857619  688161  威高骨科  15:00:00   91.99   20.00  183980   中单卖
# 4        7849787  688161  威高骨科  15:00:00   91.99   11.14  102476   中单卖
# ...          ...     ...   ...       ...     ...     ...     ...   ...
# 149995  22489584    2727   一心堂  14:51:39   33.25   36.00  119700   中单卖
# 149996  25731872     333  美的集团  14:51:39   67.89   17.00  115413   中单卖
# 149997  22490114  300643  万通智控  14:51:39   12.77  100.00  127700   中单卖
# 149998   7613745  603639   海利尔  14:51:39   17.75   71.00  126025   中单卖
# 149999   7132080  603605   珀莱雅  14:51:39  195.89    6.00  117534   中单卖
#
#         total_vol  total_amount  eat_dws  zd_vol  zd_amount  bd_vol  bd_amount
# ...

# %%
df=hq[hq.name=='科华数据']
df
# Out:
#               no  code  name      time  price   vol  amount zljk  total_vol  \
# 18819   25948402  2335  科华数据  14:59:59  25.48  57.0  145236  中单卖       57.0
# 92060   25485154  2335  科华数据  14:54:37  25.48  50.0  127400  中单卖       50.0
# 136120  25190962  2335  科华数据  14:52:23  25.48  50.0  127400  中单卖       50.0
#
#         total_amount  eat_dws  zd_vol  zd_amount  bd_vol  bd_amount
# 18819         145236      0.0       0       57.0  145236          0
# 92060         127400      0.0       0       50.0  127400          0
# 136120        127400      0.0       0       50.0  127400          0

# %%
df.groupby(['bd_amount'])['no'].apply(list).apply(lambda x:'+'.join(str(e) for e in x))
# Out:
# bd_amount
# 0    318019+280132+270754+264079+246347+141909+1182...
# 1    318164+312051+278404+270542+268804+251383+2223...
# Name: no, dtype: object

# %%
df=hq[hq.name=='平安银行'].tail(30)
from IPython.display import HTML
s  = '<script type="text/Javascript">'
s += 'var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));'
s += 'win.document.body.innerHTML = \'' + df.to_html().replace("\n",'\\') + '\';'
s += '</script>'
HTML(s)
# Out:
# <script type="text/Javascript">var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = '<table border="1" class="dataframe">\  <thead>\    <tr style="text-align: right;">\      <th></th>\      <th>no</th>\      <th>code</th>\      <th>name</th>\      <th>time</th>\      <th>price</th>\      <th>vol</th>\      <th>amount</th>\      <th>zljk</th>\      <th>total_vol</th>\      <th>total_amount</th>\      <th>eat_dws</th>\      <th>zd_vol</th>\      <th>zd_amount</th>\      <th>bd_vol</th>\      <th>bd_amount</th>\    </tr>\  </thead>\  <tbody>\    <tr>\      <th>2265474</th>\      <td>318019</td>\      <td>1</td>\      <td>平安银行</td>\      <td>09:23:27</td>\      <td>22.80</td>\      <td>50.0</td>\      <td>114000</td>\      <td>中单买</td>\      <td>50.0</td>\      <td>114000</td>\      <td>0.0</td>\      <t
# ...

# %%
s  = '<script type="text/Javascript">'
s += 'var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));'
s += 'win.document.body.innerHTML = \'' + quote[['symbol','open']].to_html().replace("\n",'\\') + '\';'
s += '</script>'
HTML(s)
# Out:
# <script type="text/Javascript">var win = window.open("", "Title", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = '<table border="1" class="dataframe">\  <thead>\    <tr style="text-align: right;">\      <th></th>\      <th>symbol</th>\      <th>open</th>\    </tr>\  </thead>\  <tbody>\    <tr>\      <th>0</th>\      <td>SZSE.002335</td>\      <td>0.00</td>\    </tr>\    <tr>\      <th>1</th>\      <td>SZSE.002335</td>\      <td>0.00</td>\    </tr>\    <tr>\      <th>2</th>\      <td>SZSE.002335</td>\      <td>0.00</td>\    </tr>\    <tr>\      <th>3</th>\      <td>SZSE.002335</td>\      <td>0.00</td>\    </tr>\    <tr>\      <th>4</th>\      <td>SZSE.002335</td>\      <td>0.00</td>\    </tr>\    <tr>\      <th>5</th>\      <td>SZSE.002335</td>\      <td>0.00</td>\    </tr>\    <tr>\      <th>6</th>\      <td>SZSE.002335</td>\   
# ...

# %%
quote=pd.read_csv(r"E:\orderflow\MarketQuote\2021-07-05\002335.csv",index_col=0)

quote['created_at']=quote.created_at.apply(lambda x:x[-15:-6])
quote['low']=quote['low'].apply(lambda x:float('%0.2f'%x))
for i in range(5):
    quote[f"bp{i+1}"]=quote.quotes.apply(lambda x:float('%0.2f'%eval(x)[i]['bid_p']) )
    quote[f"bv{i+1}"]=quote.quotes.apply(lambda x:eval(x)[i]['bid_v'] )
    quote[f"ap{i+1}"]=quote.quotes.apply(lambda x:float('%0.2f'%eval(x)[i]['ask_p']) )
    quote[f"av{i+1}"]=quote.quotes.apply(lambda x:eval(x)[i]['ask_v'] )
quote
# Out:
#            symbol                                             quotes  \
# 0     SZSE.002335  [{'bid_p': 25.3700008392334, 'bid_v': 2100, 'a...
# 1     SZSE.002335  [{'bid_p': 25.479999542236328, 'bid_v': 272000...
# 2     SZSE.002335  [{'bid_p': 25.479999542236328, 'bid_v': 275400...
# 3     SZSE.002335  [{'bid_p': 25.479999542236328, 'bid_v': 277600...
# 4     SZSE.002335  [{'bid_p': 25.479999542236328, 'bid_v': 278300...
# ...           ...                                                ...
# 3288  SZSE.002335  [{'bid_p': 25.479999542236328, 'bid_v': 9000, ...
# 3289  SZSE.002335  [{'bid_p': 25.479999542236328, 'bid_v': 9500, ...
# 3290  SZSE.002335  [{'bid_p': 25.479999542236328, 'bid_v': 10400,...
# 3291  SZSE.002335  [{'bid_p': 25.479999542236328, 'bid_v': 11000,...
# 3292  SZSE.002335  [{'bid_p': 25.479999542236328, 'bid_v': 252485...
#
#      created_at   open   high    low  price  cum_volume    cum_amount  \
# ...

# %%
hq[hq.name=='平安银行'].head(30)
# Out:
#              no  code  name      time  price      vol   amount   zljk  \
# 344    14588933     1  平安银行  11:10:57  22.86   172.00   393192   大单主买
# 1566   14578981     1  平安银行  11:10:48  22.82    81.82   186713    中单卖
# 1686   14578981     1  平安银行  11:10:48  22.82    81.82   186713    中单卖
# 3187   14566520     1  平安银行  11:10:37  22.86   161.00   368046   大单主买
# 3313   14566520     1  平安银行  11:10:37  22.86   161.00   368046   大单主买
# 3842   14561901     1  平安银行  11:10:33  22.88    56.00   128128    中单买
# 4016   14561901     1  平安银行  11:10:33  22.88    56.00   128128    中单买
# 4794   14556927     1  平安银行  11:10:28  22.83  2000.00  4566000  超大单主卖
# 6534   14549907     1  平安银行  11:10:22  22.90   104.00   238159    中单买
# 6689   14549907     1  平安银行  11:10:22  22.90   104.00   238159    中单买
# 7863   14545126     1  平安银行  11:10:17  22.88   179.00   409552   大单主买
# 7865   14545095     1  平安银行  11:10:17  22.83    67.00   152961    中单卖
# ...

# %%
54.0*2281
# Out:
# 123174.0

# %%
# Out:
#        no  code  name      time  price  vol   amount   zljk  total_vol  \
# 0  171105    34  神州数码  09:15:36  22.92  571  1308732  超大单主买        571
# 1  142018    34  神州数码  09:15:03  21.88   50   109400    中单卖         50
# 2  113762    34  神州数码  09:15:02  20.36  135   274860    中单卖        135
# 3   71356    34  神州数码  09:15:01  22.00   80   176000    中单卖         80
# 4  102839    34  神州数码  09:15:01  21.57  159   342963   大单主卖        159
#
#    total_amount  eat_dws  zd_vol  zd_amount   bd_vol  bd_amount
# 0       1185396       18   37368        553  1148028          1
# 1        109400       50  109400          0        0          0
# 2        280260      135  280260          0        0          1
# 3        176000       80  176000          0        0          0
# 4        342962      159  342962          0        0          0

# %%
hq[hq.name=='神州数码']
# Out:
#          no  code  name      time  price    vol   amount   zljk  total_vol  \
# 336   28412    34  神州数码  09:15:00  22.50   49.0   110250    中单卖       49.0
# 1081    699    34  神州数码  09:15:00  22.00   50.0   110000    中单卖       50.0
# 2363    277    34  神州数码  09:15:00  18.77  571.0  1071767  超大单主卖      571.0
#
#       total_amount  eat_dws   zd_vol  zd_amount  bd_vol  bd_amount
# 336         110250     49.0   110250        0.0       0          0
# 1081        110000     50.0   110000        0.0       0          0
# 2363       1185396    571.0  1185396        0.0       0          1

# %%
hq
# Out:
#          no    code  name      time  price    vol   amount   zljk  total_vol  \
# 0      5127     802  ST北文  09:15:00   5.28  200.0   105600    中单卖      200.0
# 1     38494    2080  中材科技  09:15:00  26.20   75.0   196500    中单卖       75.0
# 2     36442  300566  激智科技  09:15:00  27.88   38.0   105944    中单卖       38.0
# 3     38510    2080  中材科技  09:15:00  26.17   40.0   104680    中单卖       40.0
# 4     24706    2938  鹏鼎控股  09:15:00  35.48   53.0   188043    中单卖       53.0
# ...     ...     ...   ...       ...    ...    ...      ...    ...        ...
# 2359  11933      12  南 玻Ａ  09:15:00  10.59  486.0   514674  超大单主买      486.0
# 2360   7864      12  南 玻Ａ  09:15:00   9.79  486.0   475793   大单主卖      486.0
# 2361   7612      12  南 玻Ａ  09:15:00  10.59  543.0   575037  超大单主买      543.0
# 2362   6037      12  南 玻Ａ  09:15:00   9.79  543.0   531597  超大单主卖      543.0
# 2363    277      34  神州数码  09:15:00  18.77  571.0  1071767  超大单主卖      571.0
#
# ...

# %%
hq[hq.amount != hq.total_amount]
# Out:
#               no    code  name      time   price     vol  amount  zljk  \
# 18456   27327206  301009  可靠股份  14:59:59   34.54   71.80  247997     4
# 18457   27327161  300998  宁波方正  14:59:59   32.11  115.00  369265     3
# 18458   27327584  300979  华利集团  14:59:59  113.79   69.00  785151     0
# 18459   27327846  300979  华利集团  14:59:59  112.86   26.00  293436     4
# 18460   27327773  300979  华利集团  14:59:59  116.25   10.00  116250     5
# ...          ...     ...   ...       ...     ...     ...     ...   ...
# 293794  25362504  300124  汇川技术  14:42:28   69.31   49.00  339619     2
# 293795  25362455  300438  鹏辉能源  14:42:28   22.85   51.00  116535     5
# 293797  21145994    2050  三花智控  14:42:28   23.91  218.55  522553     0
# 293798  21145973     810  创维数字  14:42:28    8.46  855.00  723330     0
# 293799  21145932  300409  道氏技术  14:42:28   22.46   50.00  112300     5
#
#         total_vol  total_amount  eat_dws  zd_vol  zd_amount  bd_vol  bd_amount
# ...

# %%
hq[hq.code==301009]
# Out:
#               no    code  name      time  price     vol   amount  zljk  \
# 18456   27327206  301009  可靠股份  14:59:59  34.54   71.80   247997     4
# 19548   27326775  301009  可靠股份  14:59:58  34.64  650.26  2252500     0
# 21294   27323952  301009  可靠股份  14:59:53  34.68  150.00   520200     1
# 22704   27318244  301009  可靠股份  14:59:40  34.70  111.00   385170     3
# 23230   27316291  301009  可靠股份  14:59:37  34.68  100.00   346800     3
# ...          ...     ...   ...       ...    ...     ...      ...   ...
# 292281  25375210  301009  可靠股份  14:42:35  34.81  320.00  1113920     0
# 292706  25372715  301009  可靠股份  14:42:33  35.07   30.00   105210     5
# 292817  25370953  301009  可靠股份  14:42:32  35.06  100.00   350600     3
# 292818  25369757  301009  可靠股份  14:42:32  35.05   29.00   101644     4
# 293682  25362632  301009  可靠股份  14:42:28  35.02   38.00   133076     5
#
#         total_vol  total_amount  eat_dws   zd_vol  zd_amount  bd_vol  \
# ...

# %%
import pandas as pd
hq=pd.read_csv(r"E:\orderflow\MarketHq\2021-07-02cNonebNoneeNone.csv",header=None)
hq.columns=columns=['no','code','name','time','price','vol','amount','zljk','total_vol','total_amount','eat_dws','zd_vol','zd_amount','bd_vol','bd_amount']
hq
# Out:
#               no    code  name      time  price     vol   amount   zljk  \
# 0        8316710  688161  威高骨科  15:00:00  95.00   17.00   161500    中单买
# 1        8315396  688161  威高骨科  15:00:00  95.00   25.02   237690    中单买
# 2        8308867  688161  威高骨科  15:00:00  95.00  107.97  1025715  超大单主卖
# 3        8306701  688161  威高骨科  15:00:00  95.00   20.94   198930    中单买
# 4        8266346  688161  威高骨科  15:00:00  95.00   19.38   184110    中单买
# ...          ...     ...   ...       ...    ...     ...      ...    ...
# 3753235     6509     301  东方盛虹  09:15:00  19.00  100.00   190000    中单卖
# 3753236     4158     301  东方盛虹  09:15:00  18.50  319.00   590150  超大单主卖
# 3753237    31517      17  深中华A  09:15:00   3.47  740.00   256780    中单买
# 3753238    31216      17  深中华A  09:15:00   3.48  738.00   256824    中单买
# 3753239     1221       9  中国宝安  09:15:00  15.62  115.00   179630    中单卖
#
#          total_vol  total_amount  eat_dws  zd_vol  zd_amount  bd_vol  \
# ...

# %%
df=hq[hq.code==301022]

# %%
df.head(50)
# Out:
#              no    code  name      time  price    vol  amount   zljk  \
# 21995  25112516  301022  N海泰科  14:59:38  58.27   29.0  168983    中单买
# 22228  25111499  301022  N海泰科  14:59:36  58.28   20.0  116560    中单买
# 28116  25089069  301022  N海泰科  14:58:41  58.27   29.0  168983    中单买
# 28375  25087965  301022  N海泰科  14:58:38  58.50   20.0  117000    中单买
# 29524  25082627  301022  N海泰科  14:58:26  58.60  120.0  703200  超大单主买
# 29722  25081692  301022  N海泰科  14:58:24  58.27   30.0  174810    中单买
# 31547  25072007  301022  N海泰科  14:58:03  58.27   25.0  145675    中单买
# 34473  25055918  301022  N海泰科  14:57:32  58.27   20.0  116540    中单买
# 34562  25055619  301022  N海泰科  14:57:31  58.27   39.0  227253    中单买
# 35103  25052536  301022  N海泰科  14:57:27  58.27   24.0  139848    中单买
# 37946  25036606  301022  N海泰科  14:57:09  58.30   24.0  139920    中单买
# 38412  25033888  301022  N海泰科  14:57:05  58.30   55.0  320650   大单主买
# 38911  25031243  301022  N海泰科  14:57:01  58.27   25.0  145675    中单买
# ...

# %%
df[df.time=="09:31:30"]
# Out:
#               no    code  name      time  price   vol  amount zljk  total_vol  \
# 3571249  1364922  301022  N海泰科  09:31:30  58.00  33.0  191400  中单买       33.0
# 3571454  1361328  301022  N海泰科  09:31:30  59.04  29.0  171216  中单买       29.0
#
#          total_amount  eat_dws  zd_vol  zd_amount  bd_vol  bd_amount
# 3571249        191400      6.0   34800       27.0  156600          0
# 3571454        168220     29.0  168220        0.0       0          2

# %%
df.bd_amount.value_counts()
# Out:
# 0    720
# 1    274
# 2     67
# 3     31
# 4     15
# 5     11
# 7      6
# 6      3
# 9      1
# Name: bd_amount, dtype: int64

# %%
6001*13+6002*8+6003*5+6005*10+6006*3+6007*6+6008*6+6010*2
# Out:
# 318222

# %%
# vol是挂单手数,total_vol 成交手数,vol-total_vol 是撤单
# eat_dws 是吃单数
# total_amount 是成交金额
# zd_vol 吃单金额
# zd_amount 被动成交手数
# bd_vol 被动成交金额 = total_amount-zd_amount
# bd_amount 成交价格数  与 委托价格数 的差异数

# %%
df[df.bd_amount>5]
# Out:
#                no    code  name      time  price    vol   amount   zljk  \
# 109891   24591004  301022  N海泰科  14:53:42  58.56  184.0  1077504  超大单主买
# 477007   22010474  301022  N海泰科  14:26:17  60.10   74.0   444740   大单主买
# 485638   21947438  301022  N海泰科  14:25:26  59.80   18.0   107640    中单买
# 1482451  14740037  301022  N海泰科  11:10:07  63.72   58.0   369576   大单主买
# 2928918   5402989  301022  N海泰科  09:46:50  65.00   59.0   383500   大单主买
# 3332267   2817509  301022  N海泰科  09:35:49  67.00  110.0   737000  超大单主买
# 3382070   2517370  301022  N海泰科  09:34:48  70.00   39.0   273000    中单买
# 3691874    519348  301022  N海泰科  09:30:01  72.02   32.0   230464    中单买
# 3693735    513974  301022  N海泰科  09:30:01  72.01   16.0   115216    中单买
# 3693946    505240  301022  N海泰科  09:30:01  71.21   72.0   512711  超大单主买
#
#          total_vol  total_amount  eat_dws  zd_vol  zd_amount  bd_vol  \
# 109891       184.0       1076924    143.0  836828       41.0  240096
# ...

# %%
512711-508943
# Out:
# 3768

# %%
12362980-12337363
# Out:
# 25617

# %%
25617/23.3
# Out:
# 1099.4420600858368

# %%
hq.bd_amount.value_counts()
# Out:
# 0     2861439
# 1      625010
# 2      162795
# 3       59885
# 4       24231
# 5        9887
# 6        4470
# 7        2192
# 8        1181
# 9         752
# 10        439
# 11        274
# 12        164
# 13        121
# 14         81
# 15         64
# 17         44
# 18         41
# 16         38
# 19         30
# 20         15
# 22         14
# 21         13
# 28          8
# 24          7
# 23          6
# 30          5
# 26          4
# 25          4
# 29          3
# 27          3
# 37          3
# 31          2
# 32          2
# 33          2
# 45          1
# 65          1
# 56          1
# 49          1
# 48          1
# 36          1
# 43          1
# 40          1
# 35          1
# 34          1
# 87          1
# Name: bd_amount, dtype: int64

# %%
hq[hq.bd_amount>45]
# Out:
#                no    code  name      time   price     vol    amount   zljk  \
# 696750   19952122    2594   比亚迪  14:02:02  242.00  1636.0  39591200  超大单主买
# 749715    6135577  600702  舍得酒业  13:56:05  220.42   600.0  13178528  超大单主卖
# 2098001  10674293    2636  金安国纪  10:23:16   15.00  9000.0  13500000  超大单主卖
# 3085613   1369276  600702  舍得酒业  09:42:21  225.00  1100.0  24568176  超大单主买
# 3128640   1283446  600702  舍得酒业  09:41:03  218.50   865.0  18799857  超大单主卖
#
#          total_vol  total_amount  eat_dws    zd_vol  zd_amount   bd_vol  \
# 696750     1636.00      39562539  1555.00  37602339      81.00  1960200
# 749715      600.00      13178528   599.00  13156486       1.00    22042
# 2098001    9000.00      13643188  8994.00  13633858       6.00     9330
# 3085613    1020.69      24568176  1015.69  22671201      84.31  1896975
# 3128640     865.00      18799857   864.00  18778007       1.00    21850
#
#          bd_amount
# 696750          49
# 749715          56
# 2098001         48
# ...

# %%
df.sort_values('vol')
# Out:
#                no    code  name      time  price    vol   amount   zljk  \
# 3743804    240818  301022  N海泰科  09:20:41  73.00   14.0   102200    中单买
# 3737591    296295  301022  N海泰科  09:23:58  73.50   14.0   102900    中单买
# 3699976    432067  301022  N海泰科  09:30:00  72.04   14.0   100856    中单买
# 3691873    523507  301022  N海泰科  09:30:01  72.00   14.0   100800    中单买
# 3740250    277959  301022  N海泰科  09:23:04  73.00   15.0   109500    中单买
# ...           ...     ...   ...       ...    ...    ...      ...    ...
# 904823   18852572  301022  N海泰科  13:37:57  62.10  300.0  1863000  超大单主买
# 2561807   7690384  301022  N海泰科  10:00:12  64.69  305.0  1973045  超大单主买
# 3289642   3102699  301022  N海泰科  09:36:49  63.00  318.0  2003400  超大单主买
# 2481251   8212442  301022  N海泰科  10:02:54  64.95  359.0  2331705  超大单主买
# 1292968  16115068  301022  N海泰科  13:00:06  62.50  500.0  3125000  超大单主买
#
#          total_vol  total_amount  eat_dws  zd_vol  zd_amount   bd_vol  \
# ...

# %%
df[df.no==23848085]
# Out:
#               no    code  name      time  price   vol  amount  zljk  \
# 224230  23848085  301022  N海泰科  14:46:43   60.2  68.0  409360  大单主买
#
#         total_vol  total_amount  eat_dws  zd_vol  zd_amount  bd_vol  bd_amount
# 224230       68.0        409355     63.0  379255        5.0   30100          1

# %%
df[df.vol==81]
# Out:
#                no    code  name      time  price   vol  amount   zljk  \
# 309184   23257570  301022  N海泰科  14:40:24  61.10  81.0  494910   大单主买
# 514004   21746640  301022  N海泰科  14:22:53  59.45  81.0  481545   大单主买
# 2937536   5346440  301022  N海泰科  09:46:34  64.79  81.0  524799  超大单主买
# 3191753   3713759  301022  N海泰科  09:39:18  65.80  81.0  532980  超大单主买
#
#          total_vol  total_amount  eat_dws  zd_vol  zd_amount  bd_vol  \
# 309184        81.0        494910     15.0   91650       66.0  403260
# 514004        81.0        481513      9.0   53473       72.0  428040
# 2937536       24.0        155496      0.0       0       24.0  155496
# 3191753       37.0        243460      0.0       0       37.0  243460
#
#          bd_amount
# 309184           0
# 514004           1
# 2937536          0
# 3191753          0
