# %%
from selenium import webdriver
import time
from selenium.webdriver.chrome.options import Options

# 创建一个参数对象，用来控制chrome以无界面模式打开
chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')

# 创建浏览器对象
br = webdriver.Chrome(chrome_options=chrome_options)

# 打开一个页面
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: use options instead of chrome_options
#   # This is added back by InteractiveShellApp.init_path()

# %%
br.get('http://excalc.icfqs.com:7616/site/tdx-zbfx/page-ddlj.html')

# %%
table = br.find_element_by_class_name('data-table')
#通过标签名获取表格中所有行
# trlist = br.find_elements_by_tag_name('tr')
# print(len(trlist))

# %%
table_rows = table.find_elements_by_tag_name('tr')
print(u"总行数：", len(table_rows))
# Out:
# 总行数： 200

# %%
for row in table_rows:
     #遍历行对象，获取每一个行中所有的列对象
    tdlist = row.find_elements_by_tag_name('td')
    for col in tdlist:
         print(col.text + '\t',end='')
    print('\n')
# Out:
# 15:00:00	601156	东航物流	超大单主买	24.50	1046	256.27万	大于50万
#
# 15:00:00	601156	东航物流	大单主买	24.50	196	48.02万	30-50万
#
# 15:00:00	601156	东航物流	中单买	24.50	97	23.77万	10万-30万
#
# 15:00:00	601156	东航物流	大单主买	24.50	196	48.02万	30-50万
#
# 15:00:00	601156	东航物流	中单卖	24.50	80	19.60万	10万-30万
#
# 15:00:00	601156	东航物流	中单买	24.50	67	16.41万	10万-30万
#
# 15:00:00	601156	东航物流	中单卖	24.50	80.57	19.74万	10万-30万
#
# 15:00:00	601156	东航物流	超大单主卖	24.50	548	134.26万	大于50万
#
# 15:00:00	601156	东航物流	大单主卖	24.50	137	33.56万	30-50万
#
# 15:00:00	601156	东航物流	中单买	24.50	100	24.50万	10万-30万
#
# 15:00:00	601156	东航物流	中单买	24.50	53	12.98万	10万-30万
#
# 15:00:00	601156	东航物流	中单买	24.50	48	11.76万	10万-30万
#
# 15:00:00	601156	东航物流	中单卖	24.50	122	29.89万	10万-30万
#
# 15:00:00	601156	东航物流	中单买	24.50	42	10.29万	10万-30万
#
# 15:00:00	601156	东航物流	中单买	24.50	101	24.74万	10万-30万
#
# 15:00:00	601156	东航物流	中单卖	24.50	50	12.25万	10万-30万
#
# 15:00:00	601156	东航物流	中单卖	24.50	48	11.76万	10万-30万
#
# 15:00:00	601156	东航物流	中单卖	24.50	47	11.52万	10万-30万
#
# ...

# %%
br.close()

# %%
from urllib import request

# %%
import json
import requests
import datetime

postUrl = 'http://excalc.icfqs.com:7616/TQLEX?Entry=HQServ.hq_nlp'
# payloadData数据
payloadData ={"funcId":2,"offset":0,"count":200,"cond":"time,11700,33600|code,0000009","modname":"TickAly"}
# 请求头设置
payloadHeader = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8',
    'Connection': 'keep-alive',
    'Content-Length': '96',
    'Content-Type': 'text/plain',
    'Cookie': 'ASPSessionID=',
    'Host': 'excalc.icfqs.com:7616',
    'Origin': 'http://excalc.icfqs.com:7616',
    'Referer': 'http://excalc.icfqs.com:7616/site/tdx-zbfx/page-ddlj.html',
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36"
}

# %%
 json.dumps(payloadData)
# Out:
# '{"funcId": 2, "offset": 0, "count": 200, "cond": "time,11700,33600|code,0000009", "modname": "TickAly"}'

# %%
res = requests.post(postUrl, data=json.dumps(payloadData), headers=payloadHeader, timeout=5, allow_redirects=True)

# %%
res.text
# Out:
# '{}'

# %%
res.headers
# Out:
# {'Server': 'nginx/1.18.0', 'Date': 'Sat, 19 Jun 2021 02:57:43 GMT', 'Content-Type': 'application/octet-stream', 'Content-Length': '2', 'Connection': 'keep-alive', 'Set-Cookie': 'ASPSessionID=;path=/', 'Pragma': 'no-cache', 'Cache-Control': 'no-cache'}

# %%
import requests

cookies = {
    'ASPSessionID': '',
}

headers = {
    'Connection': 'keep-alive',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36',
    'Content-Type': 'text/plain',
    'Accept': '*/*',
    'Origin': 'http://excalc.icfqs.com:7616',
    'Referer': 'http://excalc.icfqs.com:7616/site/tdx-zbfx/page-ddlj.html',
    'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8',
}

params = (
    ('Entry', 'HQServ.hq_nlp'),
)

# data = '[{"funcId":2,"offset":0,"count":300,"cond":"time,11700,33600|code,1600000","modname":"TickAly"}]'
# data = '[{"funcId":2,"offset":10000,"count":200,"cond":"time,11700,33600","modname":"TickAly"}]'
# data = '[{"funcId":2,"offset":10000,"count":200,"cond":"time,11700,33600","modname":"TickAly"}]'
# data = '[{"funcId":4,"offset":0,"count":200,"cond":"time,11700,33600|code,1600000","modname":"TickAly"}]'
data = '[{"funcId":8,"offset":0,"count":200,"cond":"time,11700,11701|code,0301012","modname":"TickAly"}]'
response = requests.post('http://excalc.icfqs.com:7616/TQLEX', headers=headers, params=params, cookies=cookies, data=data, verify=False)
# dic=json.loads(response.text)
# dic['count']
response.text
# Out:
# '{"datas": [[12631970,16668,16771,0,"301012","N扬电",1,1,550000,330000,60,3,1014000],[12519267,16589,16808,0,"301012","N扬电",3,1,533000,514100,97,3,1616601],[11080241,15736,16693,0,"301012","N扬电",3,1,470000,324300,69,3,1088818],[11080241,15736,16693,0,"301012","N扬电",1,1,470000,324300,69,3,1088820],[10175884,15298,16589,0,"301012","N扬电",3,1,460000,324954,71,4,1387181],[10175884,15298,16589,0,"301012","N扬电",1,1,460000,326600,71,4,1410273],[9750307,15094,18138,0,"301012","N扬电",3,1,490000,323370,67,4,1325020],[9642524,15050,16669,0,"301012","N扬电",3,1,461900,73904,16,7,558814],[9625100,15042,15971,0,"301012","N扬电",3,1,459500,133056,29,5,715376],[9598523,15030,19349,0,"301012","N扬电",3,1,451500,13545,3,9,131888],[9543135,15009,17733,0,"301012","N扬电",3,1,448800,44880,10,8,391957],[9464549,14972,17758,0,"301012","N扬电",3,1,440000,110000,25,3,376180],[9423776,14953,19349,0,"301012","N扬电",3,1,434500,112970,26,3,386490],[9145001,14826,17758,0,"301012","N扬电",3,1,412500,152625,37,4,690242],[8204270,14
# ...

# %%
dic=json.loads(response.text)
dic.keys()
# Out:
# dict_keys(['datas'])

# %%
len(dic['datas'])
# Out:
# 71

# %%
7137*85
# Out:
# 606645

# %%
# amount: 606645
# amount_f: "60.66万"
# bd_amount: 1
# bd_vol: 606730
# code: "000333"
# eat_dws: 0
# market: 0
# name: "美的集团"
# no: 24871298
# price: 713700
# price_f: "71.37"
# time: "14:48:33"
# time_raw: 31713
# total_amount: 606730
# total_vol: 85
# vol: 85
# zd_amount: 85
# zd_vol: 0
# zljk: 0
# zljkname: "超大单主卖"
# ["美的集团", 0, "000333", 24871298, 31713,            713700, 85, 606645, 0,     85,       606730,        0,      0,      85,      606730, 1]
#[name,      market,code,     no,   time_second+06:00:00,pr   ,vol, amount, zljk,  total_vol, total_amount, eat_dws,zd_vol,zd_amount,bd_vol,bd_amount]

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2021, 6, 21, 16, 35, 47, 205444)

# %%
import datetime

# %%
six=datetime.datetime.now().date()+datetime.timedelta(hours=6)

# %%
six.
# Out:
# datetime.date(2021, 6, 21)

# %%
datetime.datetime.today()
# Out:
# datetime.datetime(2021, 6, 21, 17, 29, 39, 784959)

# %%
td=datetime.datetime.today()

# %%
datetime.datetime(td.year,td.month,td.day)+datetime.timedelta(hours=6)
# Out:
# datetime.datetime(2021, 6, 21, 6, 0)

# %%
t=datetime.datetime(td.year,td.month,td.day)+datetime.timedelta(hours=6,seconds=16589)
t.strftime("%H:%M:%S")
# Out:
# '10:36:29'

# %%
t=datetime.datetime(td.year,td.month,td.day)+datetime.timedelta(hours=6,seconds=33600)
t.strftime("%H:%M:%S")
# Out:
# '15:20:00'

# %%
import json

# %%
dic=json.loads(response.text)
dic['count']
# Out:
# 200

# %%
json.dumps({'time':2})
# Out:
# '{"time": 2}'
